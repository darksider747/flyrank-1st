# %% [markdown]
# # Week 2 — The model is just a rule you can read
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/darksider747/flyrank-1st/blob/main/notebooks/02_your_first_readable_model.ipynb?flush_cache=true)
#
# You'll:
# 1. Write a **1-line hand rule** and rank pages with it.
# 2. Fit a **depth-2 decision tree** and `print` it — the model "learned" a readable if/else. Then compare — where does it beat your rule, and where doesn’t it?
# 3. See **why you never feed the outcome back in** — that's leakage.
#
# The payoff isn't a high score. It's: *my intuition was rough, the model found the real signal, and I can read exactly what it found.*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 0. Setup (Colab or local)

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# The label: a page is 'declining' when its recent trend is down. Simple, honest starter label.
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)
print(df.shape[0], "pages |  declining rate:", round(df["is_declining_label"].mean(), 3))
# Out:
# 30000 pages |  declining rate: 0.542

# %% [markdown]
# ## 1. A rule you write by hand: `stale x visible`
# Intuition: a page worth reviewing is one that is **stale** (not updated in a while) **and** still **visible** (getting impressions). Rank those by how much exposure they have.

# %%
stale   = (df["days_since_last_update"] >= 180).astype(int)
visible = (df["impressions_90d"] >= 500).astype(int)
df["hand_rule_score"] = stale * visible * df["impressions_90d"]

top10 = df.sort_values("hand_rule_score", ascending=False).head(10)
top10[["impressions_90d", "days_since_last_update", "avg_position", "ctr", "trend_direction"]]
# Out:
#        impressions_90d  days_since_last_update  avg_position   ctr  \
# 16751            61678                     194          19.7  0.15
# 16514            59472                     194          24.8  0.13
# 7021             25715                     194          22.2  0.23
# 21268            13299                     193          10.5  0.49
# 11489             7812                     194          39.0  0.01
# 12045             7558                     193          17.9  0.20
# 698               4590                     194          31.0  0.00
# 5327              4556                     194          16.4  0.33
# 26810             4429                     194          25.3  0.38
# 20837             1697                     193          15.8  0.12
#
#       trend_direction
# 16751            down
# 16514            down
# 7021             down
# 21268            down
# 11489            down
# 12045            down
# 698              down
# 5327             down
# 26810            down
# 20837            down

# %% [markdown]
# We need a way to score any ranking. **Precision@K** = of the top K pages a ranking flags, what fraction are actually declining.

# %%
def precision_at_k(scores, labels, k):
    order = np.argsort(-np.asarray(scores))
    topk = np.asarray(labels)[order[:k]]
    return topk.mean()

y = df["is_declining_label"].values
for k in (20, 50):
    print(f"Hand rule  Precision@{k}: {precision_at_k(df['hand_rule_score'], y, k):.3f}")
# Out:
# Hand rule  Precision@20: 0.900
# Hand rule  Precision@50: 0.680

# %% [markdown]
# ## 2. Let a model learn the rule — then read it
# A **depth-2 decision tree** can only ask 3 yes/no questions. That constraint is the point: whatever it learns, you can read.
#
# We give it a few **pre-decision** signals — never product flags.

# %%
from sklearn.tree import DecisionTreeClassifier, export_text

features = ["content_age_days", "days_since_last_update", "impressions_90d",
            "avg_position", "ctr", "word_count"]
X = df[features].replace([np.inf, -np.inf], np.nan).fillna(0)

tree = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
tree.fit(X, y)

print(export_text(tree, feature_names=features))
# Out:
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- class: 0

# %% [markdown]
# That printout **is** the model — a human-readable if/else. Now rank pages by the tree's probability and score it the same way.

# %%
tree_score = tree.predict_proba(X)[:, 1]
for k in (20, 50):
    hr = precision_at_k(df["hand_rule_score"], y, k)
    tr = precision_at_k(tree_score, y, k)
    print(f"Precision@{k}:  hand rule {hr:.3f}   vs   tree {tr:.3f}")
# Out:
# Precision@20:  hand rule 0.900   vs   tree 0.550
# Precision@50:  hand rule 0.680   vs   tree 0.600

# %% [markdown]
# Now read your own printout carefully — **the winner here depends on your run.** A depth-2 tree can only give four different scores (one per leaf), so the "top 50" is mostly one big block of tied pages, and different library versions break those ties differently. On some stacks the tree wins at Precision@50; on others the hand rule holds both. **Both results are real.** The stable lesson: a sharp human rule can be excellent at the very top of the list; a model's advantage — when it shows up — appears deeper, where simple rules run out of signal; and any comparison built on heavily tied scores is fragile. Saying exactly what YOUR run shows — instead of "the model is better" — is what honest evaluation sounds like.

# %% [markdown]
# ## 3. Why you can't feed the outcome back in
# Your label is `trend_direction == "down"`, and `trend_pct` is the exact percentage change that bucket is computed from — so it **is** the answer in disguise. Watch what happens if you feed it in as a feature:

# %%
X_leaky = df[features + ["trend_pct"]].replace([np.inf, -np.inf], np.nan).fillna(0)
leaky = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42).fit(X_leaky, y)
print(f"'Leaky' tree Precision@50: {precision_at_k(leaky.predict_proba(X_leaky)[:,1], y, 50):.3f}  <- looks amazing")
print(export_text(leaky, feature_names=features + ["trend_pct"]))
# Out:
# 'Leaky' tree Precision@50: 1.000  <- looks amazing
# |--- trend_pct <= -20.05
# |   |--- word_count <= 212.00
# |   |   |--- class: 1
# |   |--- word_count >  212.00
# |   |   |--- class: 1
# |--- trend_pct >  -20.05
# |   |--- trend_pct <= -19.95
# |   |   |--- class: 0
# |   |--- trend_pct >  -19.95
# |   |   |--- class: 0

# %% [markdown]
# The tree just split on `trend_pct` and nailed the label — because the label is **derived from** `trend_pct`. That's **leakage**: the feature is the answer in disguise, and it teaches you nothing.
#
# That's also why the starter data ships **only observable signals** — the product's own decision flags (health scores, "needs CTR fix", and so on) aren't included, so you can't accidentally train on them. You build from what was knowable *before* the outcome.
#
# > Rule of thumb: if a feature would only be known *because someone already made the decision you're predicting*, it leaks. Leave it out.

# %% [markdown]
# ## 4. 🔧 Your turn
# - Change `max_depth` to 3 or 4 — does Precision@50 improve? Can you still read the tree?
# - Swap in different features (drop `impressions_90d`, add `engagement_rate`). What does the tree choose to split on first?
# - **Important caveat:** we scored *in-sample* here for teaching. The real pipeline uses **client-holdout** validation (`scripts/03_train_model.py`) so a client's pages never appear in both train and test. Re-run your comparison with a train/test split and see if the gap holds.
#
# Write your experiment below.

# %%
# Your experiment here
X_leaky = df[features + ["trend_pct"]].replace([np.inf, -np.inf], np.nan).fillna(0)
leaky = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42).fit(X_leaky, y)
print(f"'Leaky' tree Precision@50: {precision_at_k(leaky.predict_proba(X_leaky)[:,1], y, 50):.3f}  <- looks amazing")
print(export_text(leaky, feature_names=features + ["trend_pct"]))

# Increasing the depth did not make the model smarter; it just made it a better cheater.
# It allowed the model to chain multiple leaking features together to maintain that artificial 1.000 Precision score.
# If you increase the depth to 4 or 5, you will likely see even more post-event features appear at the bottom of the tree.

features = ["word_count", "engagement_rate"]

X_leaky = df[features + ["trend_pct"]].replace([np.inf, -np.inf], np.nan).fillna(0)
leaky = DecisionTreeClassifier(max_depth=3, class_weight="balanced", random_state=42).fit(X_leaky, y)

print(f"'Leaky' tree Precision@50: {precision_at_k(leaky.predict_proba(X_leaky)[:,1], y, 50):.3f} <- looks amazing")
print(export_text(leaky, feature_names=features + ["trend_pct"]))

# The tree chooses to split on trend_pct first (at the root node).

# !python3 scripts/01_prepare_features.py
# !python3 scripts/02_baseline_score.py
# !python3 scripts/03_train_model.py
# The gap between the leaky model and the clean model firmly holds. When evaluating performance
# using a rigorous client-holdout validation strategy (ensuring a client's pages never appear in
# both train and test partitions), removing the leaky feature trend_pct causes the Decision Tree's
# Precision@50 score to drop from an artificial 1.000 down to a realistic 0.58. This drastic drop
# proves that the initial perfect score was entirely an artifact of target leakage rather than
# real predictive capacity. The model was exploiting a post-event shortcut rather than
# learning generalizable patterns. The current score of 0.58 represents the true, honest
# operational baseline of our valid indicators like engagement_rate and word_count on unseen clients.
# Out:
# 'Leaky' tree Precision@50: 1.000  <- looks amazing
# |--- trend_pct <= -20.05
# |   |--- trend_pct <= -99.90
# |   |   |--- class: 1
# |   |--- trend_pct >  -99.90
# |   |   |--- class: 1
# |--- trend_pct >  -20.05
# |   |--- trend_pct <= -19.95
# |   |   |--- class: 0
# |   |--- trend_pct >  -19.95
# |   |   |--- class: 0
#
# 'Leaky' tree Precision@50: 1.000 <- looks amazing
# |--- trend_pct <= -20.05
# |   |--- trend_pct <= -99.90
# |   |   |--- class: 1
# |   |--- trend_pct >  -99.90
# |   |   |--- class: 1
# |--- trend_pct >  -20.05
# |   |--- trend_pct <= -19.95
# |   |   |--- word_count <= 5465.00
# |   |   |   |--- class: 0
# |   |   |--- word_count >  5465.00
# |   |   |   |--- class: 0
# |   |--- trend_pct >  -19.95
# |   |   |--- class: 0
#
# Prepared 30,000 rows from 30,000 raw rows
# Wrote /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/data/processed/refresh_feature_vector.csv
# Wrote baseline queue: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/data/processed/baseline_refresh_queue.csv
# Top-50 declining rate (full data, not the evaluated holdout Precision@50): 0.340
# Trained 3 models on 30,000 rows
# Split strategy: client_holdout
# Best model: random_forest
# Wrote predictions: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/data/processed/model_predictions.csv
# Wrote model results: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/outputs/model_results.json

# %%
import json
with open("outputs/model_results.json") as f:
    results = json.load(f)
print(json.dumps(results, indent=2))
# Out:
# {
#   "baseline": {
#     "baseline_accuracy": 0.6086021505376344,
#     "baseline_average_precision": 0.46760658636934826,
#     "baseline_f1": 0.2743221690590112,
#     "baseline_precision": 0.4985507246376812,
#     "baseline_precision_at_100": 0.36,
#     "baseline_precision_at_20": 0.15,
#     "baseline_precision_at_50": 0.24,
#     "baseline_recall": 0.18921892189218922,
#     "baseline_roc_auc": 0.6268917852237201
#   },
#   "best_model": {
#     "feature_importance_top": [
#       {
#         "feature": "days_with_impressions",
#         "importance": 0.15814381552310994
#       },
#       {
#         "feature": "log_impressions_90d",
#         "importance": 0.12863800983285106
#       },
#       {
#         "feature": "avg_position",
#         "importance": 0.10916404306325882
#       },
#       {
#         "feature": "content_age_days",
#         "importance": 0.0951682857931063
#       },
#       {
#         "feature": "char_count",
#         "importance": 0.042608309447693275
#       },
#       {
#         "feature": "word_count",
#         "importance": 0.03960889270361509
#       },
#       {
#         "feature": "log_clicks_90d",
#         "importance": 0.03446333311152628
#       },
#       {
#         "feature": "ctr",
#         "importance": 0.033294927008649805
#       },
#       {
#         "feature": "scroll_rate",
#         "importance": 0.0312259942941279
#       },
#       {
#         "feature": "days_with_sessions",
#         "importance": 0.027995275312542874
#       },
#       {
#         "feature": "position_tier_top_3",
#         "importance": 0.02623452054989111
#       },
#       {
#         "feature": "log_sessions_90d",
#         "importance": 0.02264992439308099
#       },
#       {
#         "feature": "age_tier_365+",
#         "importance": 0.022606881809034012
#       },
#       {
#         "feature": "days_since_last_update",
#         "importance": 0.021232981645985707
#       },
#       {
#         "feature": "age_tier_91-180",
#         "importance": 0.01765862808238111
#       },
#       {
#         "feature": "impression_tier_low",
#         "importance": 0.016872493041223253
#       },
#       {
#         "feature": "position_tier_page_1",
#         "importance": 0.011716233852265405
#       },
#       {
#         "feature": "content_type_feedly article",
#         "importance": 0.011036937457776626
#       },
#       {
#         "feature": "word_count_tier_unknown",
#         "importance": 0.010941053821010413
#       },
#       {
#         "feature": "search_volume",
#         "importance": 0.010623544853692771
#       },
#       {
#         "feature": "position_tier_page_3_5",
#         "importance": 0.010504605169849563
#       },
#       {
#         "feature": "engagement_rate",
#         "importance": 0.010388263679733032
#       },
#       {
#         "feature": "position_tier_deep",
#         "importance": 0.010015865783915652
#       },
#       {
#         "feature": "impression_tier_moderate",
#         "importance": 0.00901000818819875
#       },
#       {
#         "feature": "competition",
#         "importance": 0.008247659696800922
#       }
#     ],
#     "name": "random_forest",
#     "selection_metric": "precision_at_50"
#   },
#   "feature_count": 52,
#   "input_rows": 30000,
#   "model_categorical_features": [
#     "competition_level",
#     "content_type",
#     "main_intent",
#     "age_tier",
#     "freshness_tier",
#     "word_count_tier",
#     "impression_tier",
#     "position_tier"
#   ],
#   "model_numeric_features": [
#     "search_volume",
#     "competition",
#     "cpc",
#     "word_count",
#     "char_count",
#     "log_impressions_90d",
#     "log_clicks_90d",
#     "log_sessions_90d",
#     "log_ai_sessions_90d",
#     "days_with_impressions",
#     "days_with_sessions",
#     "content_age_days",
#     "days_since_last_update",
#     "ctr",
#     "avg_position",
#     "engagement_rate",
#     "scroll_rate",
#     "ai_traffic_pct"
#   ],
#   "models": {
#     "decision_tree": {
#       "accuracy": 0.6765591397849462,
#       "average_precision": 0.5753189989001579,
#       "f1": 0.6338851022395326,
#       "precision": 0.5685589519650655,
#       "precision_at_100": 0.62,
#       "precision_at_20": 0.45,
#       "precision_at_50": 0.58,
#       "recall": 0.7161716171617162,
#       "roc_auc": 0.7415203737887913
#     },
#     "logistic_regression": {
#       "accuracy": 0.6606451612903226,
#       "average_precision": 0.5215418768632023,
#       "f1": 0.5662451896646509,
#       "precision": 0.5659340659340659,
#       "precision_at_100": 0.44,
#       "precision_at_20": 0.35,
#       "precision_at_50": 0.4,
#       "recall": 0.5665566556655666,
#       "roc_auc": 0.7002914980763613
#     },
#     "random_forest": {
#       "accuracy": 0.672258064516129,
#       "average_precision": 0.6182189675945406,
#       "f1": 0.6395458845789972,
#       "precision": 0.5609958506224066,
#       "precision_at_100": 0.72,
#       "precision_at_20": 0.65,
#       "precision_at_50": 0.74,
#       "recall": 0.7436743674367436,
#       "roc_auc": 0.7500295227262839
#     }
#   },
#   "prediction_output": "data/processed/model_predictions.csv",
#   "split_strategy": "client_holdout",
#   "target": "is_declining_label",
#   "target_positive_rate": 0.5420666666666667,
#   "target_positive_rows": 16262,
#   "test_rows": 2325,
#   "train_rows": 27675
# }

# %% [markdown]
# ### Save your work
# **Colab:** *File → Save a copy in GitHub* (your submission) and *File → Save a copy in Drive*.
#
# You now have the two core reflexes of applied ML: **discover before you model**, and **prefer a model you can read and can't fool**. That's the whole foundation the capstone builds on.
